# %% [markdown]
# # Phenotypes Associated with Rare Disorders

# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
Phenotypes = pd.read_csv('Phenotypes.csv')
Phenotypes.head()
# Out:
#    @_id  Disorder/@_id  Disorder/OrphaCode  \
# 0     1              2                  58
# 1     2              3                  61
# 2     3              5                  93
# 3     4              6                 585
# 4     5              7                 118
#
#                            Disorder/ExpertLink/#text  \
# 0  http://www.orpha.net/consor/cgi-bin/OC_Exp.php...
# 1  http://www.orpha.net/consor/cgi-bin/OC_Exp.php...
# 2  http://www.orpha.net/consor/cgi-bin/OC_Exp.php...
# 3  http://www.orpha.net/consor/cgi-bin/OC_Exp.php...
# 4  http://www.orpha.net/consor/cgi-bin/OC_Exp.php...
#
#   Disorder/ExpertLink/@_lang            Disorder/Name/#text  \
# 0                         en              Alexander disease
# 1                         en             Alpha-mannosidosis
# 2                         en         Aspartylglucosaminuria
# 3                         en  Multiple sulfatase deficiency
# 4                         en              Beta-mannosidosis
#
# ...

# %%
Phenotypes.columns
# Out:
# Index(['@_id', 'Disorder/@_id', 'Disorder/OrphaCode',
#        'Disorder/ExpertLink/#text', 'Disorder/ExpertLink/@_lang',
#        'Disorder/Name/#text', 'Disorder/Name/@_lang',
#        'Disorder/DisorderType/@_id', 'Disorder/DisorderType/Name/#text',
#        'Disorder/DisorderType/Name/@_lang',
#        ...
#        'Disorder/HPODisorderAssociationList/HPODisorderAssociation/81/DiagnosticCriteria/Name/@_lang',
#        'Disorder/HPODisorderAssociationList/HPODisorderAssociation/83/DiagnosticCriteria/@_id',
#        'Disorder/HPODisorderAssociationList/HPODisorderAssociation/83/DiagnosticCriteria/Name/#text',
#        'Disorder/HPODisorderAssociationList/HPODisorderAssociation/83/DiagnosticCriteria/Name/@_lang',
#        'Disorder/HPODisorderAssociationList/HPODisorderAssociation/47/DiagnosticCriteria/@_id',
#        'Disorder/HPODisorderAssociationList/HPODisorderAssociation/47/DiagnosticCriteria/Name/#text',
# ...

# %%
Phenotypes_subset = Phenotypes.loc[:,['Disorder/OrphaCode','Disorder/Name/#text','Disorder/DisorderType/Name/#text','Disorder/HPODisorderAssociationList/HPODisorderAssociation/0/HPO/HPOTerm','Disorder/HPODisorderAssociationList/HPODisorderAssociation/0/HPOFrequency/Name/#text','Disorder/HPODisorderAssociationList/HPODisorderAssociation/1/HPO/HPOTerm','Disorder/HPODisorderAssociationList/HPODisorderAssociation/1/HPOFrequency/Name/#text','Disorder/HPODisorderAssociationList/HPODisorderAssociation/2/HPO/HPOTerm','Disorder/HPODisorderAssociationList/HPODisorderAssociation/2/HPOFrequency/Name/#text','Disorder/HPODisorderAssociationList/HPODisorderAssociation/3/HPO/HPOTerm','Disorder/HPODisorderAssociationList/HPODisorderAssociation/3/HPOFrequency/Name/#text','Disorder/HPODisorderAssociationList/HPODisorderAssociation/4/HPO/HPOTerm','Disorder/HPODisorderAssociationList/HPODisorderAssociation/4/HPOFrequency/Name/#text','Disorder/HPODisorderAssociationList/HPODisorderAssociation/5/HPO/HPOTerm','Disorder/HPODisorderAssociationList/HPODisorderAssociation/5/HPOFrequency/Name/#text','Disorder/HPODisorderAssociationList/HPODisorderAssociation/6/HPO/HPOTerm','Disorder/HPODisorderAssociationList/HPODisorderAssociation/6/HPOFrequency/Name/#text','Disorder/HPODisorderAssociationList/HPODisorderAssociation/7/HPO/HPOTerm','Disorder/HPODisorderAssociationList/HPODisorderAssociation/7/HPOFrequency/Name/#text','Disorder/HPODisorderAssociationList/HPODisorderAssociation/8/HPO/HPOTerm','Disorder/HPODisorderAssociationList/HPODisorderAssociation/8/HPOFrequency/Name/#text','Disorder/HPODisorderAssociationList/HPODisorderAssociation/9/HPO/HPOTerm','Disorder/HPODisorderAssociationList/HPODisorderAssociation/9/HPOFrequency/Name/#text','Disorder/HPODisorderAssociationList/HPODisorderAssociation/10/HPO/HPOTerm','Disorder/HPODisorderAssociationList/HPODisorderAssociation/10/HPOFrequency/Name/#text','Disorder/HPODisorderAssociationList/HPODisorderAssociation/11/HPO/HPOTerm','Disorder/HPODisorderAssociationList/HPODisorderAssociation/11/HPOFrequency/Name/#text']]

# %%
Phenotypes_subset.columns
# Out:
# Index(['Disorder/OrphaCode', 'Disorder/Name/#text',
#        'Disorder/DisorderType/Name/#text',
#        'Disorder/HPODisorderAssociationList/HPODisorderAssociation/0/HPO/HPOTerm',
#        'Disorder/HPODisorderAssociationList/HPODisorderAssociation/0/HPOFrequency/Name/#text',
#        'Disorder/HPODisorderAssociationList/HPODisorderAssociation/1/HPO/HPOTerm',
#        'Disorder/HPODisorderAssociationList/HPODisorderAssociation/1/HPOFrequency/Name/#text',
#        'Disorder/HPODisorderAssociationList/HPODisorderAssociation/2/HPO/HPOTerm',
#        'Disorder/HPODisorderAssociationList/HPODisorderAssociation/2/HPOFrequency/Name/#text',
#        'Disorder/HPODisorderAssociationList/HPODisorderAssociation/3/HPO/HPOTerm',
#        'Disorder/HPODisorderAssociationList/HPODisorderAssociation/3/HPOFrequency/Name/#text',
#        'Disorder/HPODisorderAssociationList/HPODisorderAssociation/4/HPO/HPOTerm',
# ...

# %%
Phenotypes_subset.rename(columns = {'Disorder/OrphaCode':'OrphaCode'}, inplace = True) 
Phenotypes_subset.rename(columns = {'Disorder/Name/#text':'DisorderName'}, inplace = True) 
Phenotypes_subset.rename(columns = {'Disorder/DisorderType/Name/#text':'DisorderType'}, inplace = True)
Phenotypes_subset.rename(columns = {'Disorder/HPODisorderAssociationList/HPODisorderAssociation/0/HPO/HPOTerm':'HPOTerm0'}, inplace = True)
Phenotypes_subset.rename(columns = {'Disorder/HPODisorderAssociationList/HPODisorderAssociation/1/HPO/HPOTerm':'HPOTerm1'}, inplace = True)
Phenotypes_subset.rename(columns = {'Disorder/HPODisorderAssociationList/HPODisorderAssociation/2/HPO/HPOTerm':'HPOTerm2'}, inplace = True)
Phenotypes_subset.rename(columns = {'Disorder/HPODisorderAssociationList/HPODisorderAssociation/3/HPO/HPOTerm':'HPOTerm3'}, inplace = True)
Phenotypes_subset.rename(columns = {'Disorder/HPODisorderAssociationList/HPODisorderAssociation/4/HPO/HPOTerm':'HPOTerm4'}, inplace = True)
Phenotypes_subset.rename(columns = {'Disorder/HPODisorderAssociationList/HPODisorderAssociation/5/HPO/HPOTerm':'HPOTerm5'}, inplace = True)
Phenotypes_subset.rename(columns = {'Disorder/HPODisorderAssociationList/HPODisorderAssociation/6/HPO/HPOTerm':'HPOTerm6'}, inplace = True)
Phenotypes_subset.rename(columns = {'Disorder/HPODisorderAssociationList/HPODisorderAssociation/7/HPO/HPOTerm':'HPOTerm7'}, inplace = True)
Phenotypes_subset.rename(columns = {'Disorder/HPODisorderAssociationList/HPODisorderAssociation/8/HPO/HPOTerm':'HPOTerm8'}, inplace = True)
Phenotypes_subset.rename(columns = {'Disorder/HPODisorderAssociationList/HPODisorderAssociation/9/HPO/HPOTerm':'HPOTerm9'}, inplace = True)
Phenotypes_subset.rename(columns = {'Disorder/HPODisorderAssociationList/HPODisorderAssociation/10/HPO/HPOTerm':'HPOTerm10'}, inplace = True)
Phenotypes_subset.rename(columns = {'Disorder/HPODisorderAssociationList/HPODisorderAssociation/11/HPO/HPOTerm':'HPOTerm11'}, inplace = True)
Phenotypes_subset.rename(columns = {'Disorder/HPODisorderAssociationList/HPODisorderAssociation/0/HPOFrequency/Name/#text':'HPOFrequency0'}, inplace = True)
Phenotypes_subset.rename(columns = {'Disorder/HPODisorderAssociationList/HPODisorderAssociation/1/HPOFrequency/Name/#text':'HPOFrequency1'}, inplace = True)
Phenotypes_subset.rename(columns = {'Disorder/HPODisorderAssociationList/HPODisorderAssociation/2/HPOFrequency/Name/#text':'HPOFrequency2'}, inplace = True)
Phenotypes_subset.rename(columns = {'Disorder/HPODisorderAssociationList/HPODisorderAssociation/3/HPOFrequency/Name/#text':'HPOFrequency3'}, inplace = True)
Phenotypes_subset.rename(columns = {'Disorder/HPODisorderAssociationList/HPODisorderAssociation/4/HPOFrequency/Name/#text':'HPOFrequency4'}, inplace = True)
Phenotypes_subset.rename(columns = {'Disorder/HPODisorderAssociationList/HPODisorderAssociation/5/HPOFrequency/Name/#text':'HPOFrequency5'}, inplace = True)
Phenotypes_subset.rename(columns = {'Disorder/HPODisorderAssociationList/HPODisorderAssociation/6/HPOFrequency/Name/#text':'HPOFrequency6'}, inplace = True)
Phenotypes_subset.rename(columns = {'Disorder/HPODisorderAssociationList/HPODisorderAssociation/7/HPOFrequency/Name/#text':'HPOFrequency7'}, inplace = True)
Phenotypes_subset.rename(columns = {'Disorder/HPODisorderAssociationList/HPODisorderAssociation/8/HPOFrequency/Name/#text':'HPOFrequency8'}, inplace = True)
Phenotypes_subset.rename(columns = {'Disorder/HPODisorderAssociationList/HPODisorderAssociation/9/HPOFrequency/Name/#text':'HPOFrequency9'}, inplace = True)
Phenotypes_subset.rename(columns = {'Disorder/HPODisorderAssociationList/HPODisorderAssociation/10/HPOFrequency/Name/#text':'HPOFrequency10'}, inplace = True)
Phenotypes_subset.rename(columns = {'Disorder/HPODisorderAssociationList/HPODisorderAssociation/11/HPOFrequency/Name/#text':'HPOFrequency11'}, inplace = True)

# %%
Phenotypes_subset.shape
# Out:
# (4041, 27)

# %%
num_rows = Phenotypes_subset.shape[0]
num_missing = num_rows - Phenotypes_subset.count()
num_missing.sum()
# Out:
# 9580

# %%
missing_val_count_by_column = Phenotypes_subset.isnull().sum()
missing_val_count_by_column
# Out:
# OrphaCode           0
# DisorderName        0
# DisorderType        0
# HPOTerm0            2
# HPOFrequency0       2
# HPOTerm1            2
# HPOFrequency1       2
# HPOTerm2           52
# HPOFrequency2      52
# HPOTerm3          126
# HPOFrequency3     126
# HPOTerm4          203
# HPOFrequency4     203
# HPOTerm5          293
# HPOFrequency5     293
# HPOTerm6          398
# HPOFrequency6     398
# HPOTerm7          516
# HPOFrequency7     516
# HPOTerm8          623
# HPOFrequency8     623
# HPOTerm9          736
# HPOFrequency9     736
# HPOTerm10         857
# HPOFrequency10    857
# HPOTerm11         982
# HPOFrequency11    982
# dtype: int64

# %%
Phenotypes_subset = Phenotypes_subset.dropna()

# %%
Phenotypes_subset.shape
# Out:
# (3059, 27)

# %%
Phenotypes_subset.nunique()
# Out:
# OrphaCode         3059
# DisorderName      3059
# DisorderType        10
# HPOTerm0           933
# HPOFrequency0        6
# HPOTerm1          1052
# HPOFrequency1        6
# HPOTerm2          1119
# HPOFrequency2        6
# HPOTerm3          1158
# HPOFrequency3        6
# HPOTerm4          1179
# HPOFrequency4        6
# HPOTerm5          1208
# HPOFrequency5        6
# HPOTerm6          1260
# HPOFrequency6        6
# HPOTerm7          1258
# HPOFrequency7        6
# HPOTerm8          1331
# HPOFrequency8        5
# HPOTerm9          1378
# HPOFrequency9        6
# HPOTerm10         1414
# HPOFrequency10       6
# HPOTerm11         1484
# HPOFrequency11       6
# dtype: int64

# %%
Phenotypes_subset.head()
# Out:
#    OrphaCode                   DisorderName DisorderType         HPOTerm0  \
# 0         58              Alexander disease      Disease     Macrocephaly
# 1         61             Alpha-mannosidosis      Disease     Macroglossia
# 2         93         Aspartylglucosaminuria      Disease  Inguinal hernia
# 3        585  Multiple sulfatase deficiency      Disease    Hydrocephalus
# 5        141                Canavan disease      Disease     Macrocephaly
#
#             HPOFrequency0                 HPOTerm1           HPOFrequency1  \
# 0  Very frequent (99-80%)  Intellectual disability  Very frequent (99-80%)
# 1  Very frequent (99-80%)   Coarse facial features  Very frequent (99-80%)
# 2      Occasional (29-5%)           Macroorchidism       Frequent (79-30%)
# 3       Frequent (79-30%)             Microcephaly      Occasional (29-5%)
# 5       Frequent (79-30%)       Hearing impairment       Frequent (79-30%)
#
# ...

# %%
Phenotypes_subset.loc[0,['DisorderName']]
# Out:
# DisorderName    Alexander disease
# Name: 0, dtype: object

# %%
Phenotypes_subset.iloc[0,1]
# Out:
# 'Alexander disease'

# %%
HPOTerms = []
HPOFrequencies = []
for columnNumber in range(3,25):
    if columnNumber % 2 == 0:
        HPOFrequencies.append(Phenotypes_subset.iloc[0,columnNumber])
    else:
        HPOTerms.append(Phenotypes_subset.iloc[0,columnNumber])

# %%
AlexanderDisease = pd.DataFrame({
    'HPOTerms': HPOTerms,
    'HPOFrequencies': HPOFrequencies
})
AlexanderDisease
# Out:
#                           HPOTerms          HPOFrequencies
# 0                     Macrocephaly  Very frequent (99-80%)
# 1          Intellectual disability  Very frequent (99-80%)
# 2                         Seizures  Very frequent (99-80%)
# 3                       Spasticity  Very frequent (99-80%)
# 4      Agenesis of corpus callosum  Very frequent (99-80%)
# 5                    Hyperreflexia  Very frequent (99-80%)
# 6                   Megalencephaly  Very frequent (99-80%)
# 7                Failure to thrive  Very frequent (99-80%)
# 8                  Frontal bossing  Very frequent (99-80%)
# 9              Nausea and vomiting  Very frequent (99-80%)
# 10  Neurological speech impairment  Very frequent (99-80%)

# %%
Phenotypes_subset.to_csv('Phenotypes_subset.csv', index=False)
